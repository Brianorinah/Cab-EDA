# %%
from datetime import datetime 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2021, 3, 10, 9, 18, 47, 557662)

# %%
str(now)
now1 = datetime(2011,2,22)

# %%
now.strftime('%y-%m-%d')
# Out:
# '21-03-10'

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5), datetime(2011, 1, 7), datetime(2011, 1, 8),
datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.randn(6), index=dates)

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
data = np.random.randn(1000)
props ={
    "title":"Title 2",
    "xlabel":"new x",
    "ylabel":"new y",
    "xticks": [0,250,500,750,1000] ,
    "xticklabels": ['one','two','three','four','five']
}
ax.set(**props)
ax.plot(data.cumsum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-9da4997f8aa2> in <module>
#       1 fig = plt.figure()
# ----> 2 fig.pie()
#
# AttributeError: 'Figure' object has no attribute 'pie'

# %%
# %config InlineBackend.figure_format = "retina"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity ="all"

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1f3867fc088>)

# %%
fig , ax = plt.subplots()

# %%
fig2, ax2 = plt.subplots()

# %%
ax2

# %%
fig2
